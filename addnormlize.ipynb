# %% [markdown]
# # Prepare
# ## Dataset loading

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import Callback
from tqdm import tqdm

train_raw = pd.read_excel('/home/competition/data/data/ai_competition_train.xlsx')
test_raw = pd.read_excel('/home/competition/data/data/ai_competition_test.xlsx')

train = np.array(train_raw['flux'])
test = np.array(test_raw['flux'])

print(train.shape, test.shape)
# Out:
# (5479,) (60,)

# %% [markdown]
# ## Nan -> zero (Only train)

# %%
# NaN 값을 0.0으로 대체
nan_indices = np.isnan(train)
_mask = np.zeros(len(train))
train[nan_indices] = _mask[nan_indices]

# NaN 값을 대체한 결과 확인
print(train)
print(np.mean(train))
print("NaN 값의 개수:", np.sum(np.isnan(test)))
# Out:
# [ 94.8    96.93   97.71  ...   0.    128.634 143.651]
# 78.29537461215551
# NaN 값의 개수: 0

# %% [markdown]
# ## Cut zero (Only train)
# - 인위적인 이동평균을 넣어주는 것은 오히려 악영향이라고 생각 > 끊어진 부분 강제로 이어붙임으로서 그것 또한 노이즈하고 생각하기

# %%
train_cut = train[train != 0]
print(train_cut.shape)
print(np.mean(train_cut))
# Out:
# (4228,)
# 101.46176856669818

# %%
plt.figure()
plt.plot(train, label='train')
plt.plot(train_cut, label='train_cut')
plt.xlabel('Index')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Make dataset

# %%
# normalize
# 1. min-max normalization
# 2. subtract mean
print(np.var(train_cut))
train_norm = (train_cut - np.min(train_cut)) / (np.max(train_cut) - np.min(train_cut))
train_norm_sub_mean = train_norm - np.mean(train_norm)
print(np.var(train_norm_sub_mean))

# windows shift
INPUT_DAYS = 60

train_x = np.zeros([INPUT_DAYS, 1])
train_y = np.zeros([1, 1])

print("x and y shape :", train_x.shape, train_y.shape)
for i in range(len(train_norm_sub_mean) - INPUT_DAYS - 1):
    train_x = np.concatenate(
        (train_x, train_norm_sub_mean[i:i+INPUT_DAYS, np.newaxis]), axis=1)
    train_y = np.concatenate(
        (train_y, train_norm_sub_mean[np.newaxis, i+INPUT_DAYS+1, np.newaxis]), axis=1)

print("x and y shape :", train_x.shape, train_y.shape)
train_x = train_x[:, 1:]
train_y = train_y[:, 1:]
train_x = train_x.T
train_y = train_y.T
print("x and y shape :", train_x.shape, train_y.shape)
print(np.var(train_x), np.var(train_y))
# Out:
# 926.6917847239336
# 0.025033707731746426
# x and y shape : (60, 1) (1, 1)
# x and y shape : (60, 4168) (1, 4168)
# x and y shape : (4167, 60) (4167, 1)
# 0.025304498927576333 0.02529762027554298

# %%
loss_history = []


class LossHistory(Callback):
    def on_epoch_end(self, epoch, logs=None):
        loss_history.append(logs['loss'])


loss_callback = LossHistory()

# %% [markdown]
# ---

# %% [markdown]
# # Model

# %%
model = keras.Sequential()
model.add(keras.layers.LSTM(units=80, input_shape=(INPUT_DAYS, 1)))
model.add(keras.layers.Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['RootMeanSquaredError'])

# %%
model.fit(train_x, train_y, epochs=40, batch_size=64, callbacks=[loss_callback])
# Out:
# Epoch 1/40
# 66/66 [==============================] - 4s 27ms/step - loss: 0.0098 - root_mean_squared_error: 0.0989
# Epoch 2/40
# 66/66 [==============================] - 2s 32ms/step - loss: 0.0067 - root_mean_squared_error: 0.0819
# Epoch 3/40
# 66/66 [==============================] - 2s 26ms/step - loss: 0.0056 - root_mean_squared_error: 0.0750
# Epoch 4/40
# 66/66 [==============================] - 2s 24ms/step - loss: 0.0054 - root_mean_squared_error: 0.0736
# Epoch 5/40
# 66/66 [==============================] - 2s 27ms/step - loss: 0.0052 - root_mean_squared_error: 0.0718
# Epoch 6/40
# 66/66 [==============================] - 2s 25ms/step - loss: 0.0050 - root_mean_squared_error: 0.0709
# Epoch 7/40
# 66/66 [==============================] - 2s 27ms/step - loss: 0.0050 - root_mean_squared_error: 0.0706
# Epoch 8/40
# 66/66 [==============================] - 2s 27ms/step - loss: 0.0049 - root_mean_squared_error: 0.0703
# Epoch 9/40
# 66/66 [==============================] - 2s 26ms/step - loss: 0.0049 - root_mean_squared_error: 0.0700
# Epoch 10/40
# 66/66 [==============================] - 2s 27ms/step - loss: 0.0049 - root_mean_squared_error: 0.0698
# Epoch 11/40
# 66/66 [==============================] - 2s 27ms/step - loss: 0.0049 - root_mean_squared_error: 0.0697
# Epoch 12/40
# 66/66 [==============================] - 2s 27ms/step - loss: 0.0049 - root_mean_squared_error: 0.0697
# Epoch 13/40
# 66/66 [==============================] - 2s 26ms/step - loss: 0.0048 - root_mean_squared_error: 0.0695
# Epoch 14/40
# 66/66 [==============================] - 2s 26ms/step - loss: 0.0047 - root_mean_squared_error: 0.0687
# Epoch 15/40
# 66/66 [==============================] - 2s 28ms/step - loss: 0.0047 - root_mean_squared_error: 0.0687
# Epoch 16/40
# 66/66 [==============================] - 2s 27ms/step - loss: 0.0047 - root_mean_squared_error: 0.0689
# Epoch 17/40
# 66/66 [==============================] - 2s 27ms/step - loss: 0.0048 - root_mean_squared_error: 0.0689
# Epoch 18/40
# 66/66 [==============================] - 2s 29ms/step - loss: 0.0047 - root_mean_squared_error: 0.0687
# Epoch 19/40
# 66/66 [==============================] - 2s 28ms/step - loss: 0.0048 - root_mean_squared_error: 0.0691
# Epoch 20/40
# 66/66 [==============================] - 2s 27ms/step - loss: 0.0047 - root_mean_squared_error: 0.0687
# Epoch 21/40
# 66/66 [==============================] - 2s 28ms/step - loss: 0.0048 - root_mean_squared_error: 0.0689
# Epoch 22/40
# 66/66 [==============================] - 2s 29ms/step - loss: 0.0047 - root_mean_squared_error: 0.0685
# Epoch 23/40
# 66/66 [==============================] - 2s 28ms/step - loss: 0.0047 - root_mean_squared_error: 0.0683
# Epoch 24/40
# 66/66 [==============================] - 2s 29ms/step - loss: 0.0047 - root_mean_squared_error: 0.0685
# Epoch 25/40
# 66/66 [==============================] - 2s 27ms/step - loss: 0.0047 - root_mean_squared_error: 0.0686
# Epoch 26/40
# 66/66 [==============================] - 2s 27ms/step - loss: 0.0047 - root_mean_squared_error: 0.0686
# Epoch 27/40
# 66/66 [==============================] - 2s 28ms/step - loss: 0.0047 - root_mean_squared_error: 0.0683
# Epoch 28/40
# 66/66 [==============================] - 2s 27ms/step - loss: 0.0047 - root_mean_squared_error: 0.0682
# Epoch 29/40
# 66/66 [==============================] - 2s 27ms/step - loss: 0.0046 - root_mean_squared_error: 0.0680
# Epoch 30/40
# 66/66 [==============================] - 2s 28ms/step - loss: 0.0047 - root_mean_squared_error: 0.0683
# Epoch 31/40
# 66/66 [==============================] - 2s 27ms/step - loss: 0.0047 - root_mean_squared_error: 0.0683
# Epoch 32/40
# 66/66 [==============================] - 2s 28ms/step - loss: 0.0046 - root_mean_squared_error: 0.0676
# Epoch 33/40
# 66/66 [==============================] - 2s 27ms/step - loss: 0.0046 - root_mean_squared_error: 0.0675
# Epoch 34/40
# 66/66 [==============================] - 2s 27ms/step - loss: 0.0046 - root_mean_squared_error: 0.0678
# Epoch 35/40
# 66/66 [==============================] - 2s 28ms/step - loss: 0.0047 - root_mean_squared_error: 0.0683
# Epoch 36/40
# 66/66 [==============================] - 2s 29ms/step - loss: 0.0046 - root_mean_squared_error: 0.0680
# Epoch 37/40
# 66/66 [==============================] - 2s 29ms/step - loss: 0.0045 - root_mean_squared_error: 0.0674
# Epoch 38/40
# 66/66 [==============================] - 2s 27ms/step - loss: 0.0045 - root_mean_squared_error: 0.0672
# Epoch 39/40
# 66/66 [==============================] - 2s 27ms/step - loss: 0.0045 - root_mean_squared_error: 0.0672
# Epoch 40/40
# 66/66 [==============================] - 2s 27ms/step - loss: 0.0047 - root_mean_squared_error: 0.0686

# %%
plt.plot(loss_history)
plt.title('Training Loss Over Time')
plt.legend(['loss_history', 'rmse_history'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # Prediction

# %% [markdown]
# - input 60개로 61번째 예측
# - 2번째 ~ 61번째로, 62번째 예측
# - 90번째를 예측할 때 까지 반복하고, 61~90번째를 제출

# %%
test_max = np.max(test)
test_min = np.min(test)


test_norm = (test - np.min(test)) / (np.max(test) - np.min(test))
test_mean = np.mean(test_norm)
test_norm_sub_mean = test_norm - test_mean
final_result = test_norm_sub_mean

for i in tqdm(range(30)):
    _single_output = model(
        final_result[np.newaxis, i:i+INPUT_DAYS, np.newaxis]).numpy()
    final_result = np.concatenate((final_result, _single_output[0]), axis=0)    
    
    
# Subtract mean했던거 다시 더해주기

final_result = final_result + test_mean*0.985
final_result = final_result * (test_max - test_min) + test_min

_summit = final_result[-30:]


plt.figure()
plt.plot(final_result+test_mean, label='output')
plt.plot(test, label='input')
plt.xlabel('Index')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 100%|██████████| 30/30 [00:02<00:00, 14.04it/s]

# %% [markdown]
# ## output xlsx file 생성

# %%
import datetime

current_time = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
df = pd.DataFrame({'date': np.array(range(1,31)), 'flux': _summit})

# DataFrame을 엑셀 파일로 내보내기
file_name = f'/home/competition/data/data/dev/{current_time}_output_{loss_history[-1]}.xlsx'
df.to_excel(file_name, index=False)

model_name = f'/home/competition/data/data/dev/{current_time}_model_{loss_history[-1]}.h5'
model.save(model_name)
# Out:
# /home/competition/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
